# %%
import pandas as pd
#import datetime as dt

# %%
first_data = pd.read_csv("201803-citibike-tripdata.csv")
combined_data = pd.DataFrame(first_data)
combined_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           816  2018-03-01 02:29:13.7270  2018-03-01 02:42:50.1460
# 1           235  2018-03-01 05:12:37.0320  2018-03-01 05:16:32.1010
# 2          1250  2018-03-01 05:45:49.9000  2018-03-01 06:06:39.9080
# 3           741  2018-03-01 06:54:19.6150  2018-03-01 07:06:40.9790
# 4           727  2018-03-01 07:08:38.8610  2018-03-01 07:20:46.8500
#
#    start station id start station name  start station latitude  \
# 0                72   W 52 St & 11 Ave               40.767272
# 1                72   W 52 St & 11 Ave               40.767272
# 2                72   W 52 St & 11 Ave               40.767272
# 3                72   W 52 St & 11 Ave               40.767272
# 4                72   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id               end station name  \
# 0               -73.993929             379                W 31 St & 7 Ave
# ...

# %%
for i in range(201804, 201812):
    file_to_load = str(i) + "-citibike-tripdata.csv"
    bike_data = pd.read_csv(file_to_load)
    #combined_data = pd.concat([combined_data, bike_data], ignore_index = True )
    combined_data = combined_data.append(bike_data)

# %%
len(combined_data.index)
# Out:
# 13709371

# %%
starttime2 = pd.to_datetime(combined_data.starttime, errors='coerce')
stoptime2 = pd.to_datetime(combined_data.stoptime, errors='coerce')
new_data = combined_data.assign(start_date=starttime2.dt.date, start_hour=starttime2.dt.hour, 
                                stop_date = stoptime2.dt.date, stop_hour=stoptime2.dt.hour)
new_data.replace({'gender': {0: 'Unknown', 1: 'Male', 2: 'Female'}}, inplace=True)

# %%
new_data.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           816  2018-03-01 02:29:13.7270  2018-03-01 02:42:50.1460
# 1           235  2018-03-01 05:12:37.0320  2018-03-01 05:16:32.1010
# 2          1250  2018-03-01 05:45:49.9000  2018-03-01 06:06:39.9080
# 3           741  2018-03-01 06:54:19.6150  2018-03-01 07:06:40.9790
# 4           727  2018-03-01 07:08:38.8610  2018-03-01 07:20:46.8500
#
#    start station id start station name  start station latitude  \
# 0              72.0   W 52 St & 11 Ave               40.767272
# 1              72.0   W 52 St & 11 Ave               40.767272
# 2              72.0   W 52 St & 11 Ave               40.767272
# 3              72.0   W 52 St & 11 Ave               40.767272
# 4              72.0   W 52 St & 11 Ave               40.767272
#
#    start station longitude  end station id               end station name  \
# 0               -73.993929           379.0                W 31 St & 7 Ave
# ...

# %%
new_data.to_csv("combined_bike_tripdata.csv")
